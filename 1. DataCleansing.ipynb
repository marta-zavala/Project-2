# %%
# Importo librerias

import pandas as pd
import numpy as np
import re
import src.funciones as fn

#import matplotlib.pyplot as plt
#import seaborn as sns

# %%
# Importo el archivo csv
df=pd.read_csv('Input/listings_detailed.csv')
df_clean=pd.read_csv('Input/listings.csv')

display(df.head())
print(df.shape)
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (43,61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       id                         listing_url       scrape_id last_scraped  \
# 0   6369   https://www.airbnb.com/rooms/6369  20190919050215   2019-09-19
# 1  21853  https://www.airbnb.com/rooms/21853  20190919050215   2019-09-19
# 2  24805  https://www.airbnb.com/rooms/24805  20190919050215   2019-09-19
# 3  24836  https://www.airbnb.com/rooms/24836  20190919050215   2019-09-19
# 4  26825  https://www.airbnb.com/rooms/26825  20190919050215   2019-09-19
#
#                                                 name  \
# 0  Rooftop terrace room with ensuite bathroom, Airc.
# 1                               Bright and airy room
# 2                             Gran Via Studio Madrid
# 3                     Select the Madrid more "cool".
# ...

# %%
display(df_clean.head())
print(df_clean.shape)
# Out:
#       id                                               name  host_id  \
# 0   6369  Rooftop terrace room with ensuite bathroom, Airc.    13660
# 1  21853                               Bright and airy room    83531
# 2  24805                             Gran Via Studio Madrid   101471
# 3  24836                     Select the Madrid more "cool".   101653
# 4  26825                 Single Room whith private Bathroom   114340
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0     Simon           Chamartín  Hispanoamérica  40.45628   -3.67763
# 1     Abdel              Latina        Cármenes  40.40341   -3.74084
# 2    Iraido              Centro     Universidad  40.42202   -3.70395
# 3     Tenty              Centro        Justicia  40.41995   -3.69764
# 4  Agustina          Arganzuela         Legazpi  40.38985   -3.69011
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Analizo las columnas
print('-> Datos listings_detailed:')
for i in df.columns:
    print (i)
print('\n-> Datos listings:')
for i in df_clean.columns:
    print (i)
# Out:
# -> Datos listings_detailed:
# id
# listing_url
# scrape_id
# last_scraped
# name
# summary
# space
# description
# experiences_offered
# neighborhood_overview
# notes
# transit
# access
# interaction
# house_rules
# thumbnail_url
# medium_url
# picture_url
# xl_picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# street
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# city
# state
# zipcode
# market
# smart_location
# country_code
# country
# latitude
# longitude
# is_location_exact
# property_type
# room_type
# accommodates
# bathrooms
# bedrooms
# beds
# bed_type
# amenities
# square_feet
# price
# weekly_price
# monthly_price
# security_deposit
# cleaning_fee
# ...

# %%
# Creo un nuevo dataframe con los datos que me interesan

data=df_clean[['id','name','neighbourhood_group','neighbourhood','latitude','longitude','room_type','price','minimum_nights']]
add=df[['id','listing_url','description','accommodates','amenities']]

# %%
airbnb = pd.merge(left=data,right=add, how='left', left_on='id', right_on='id')
airbnb.head()
# Out:
#       id                                               name  \
# 0   6369  Rooftop terrace room with ensuite bathroom, Airc.
# 1  21853                               Bright and airy room
# 2  24805                             Gran Via Studio Madrid
# 3  24836                     Select the Madrid more "cool".
# 4  26825                 Single Room whith private Bathroom
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0           Chamartín  Hispanoamérica  40.45628   -3.67763     Private room
# 1              Latina        Cármenes  40.40341   -3.74084     Private room
# 2              Centro     Universidad  40.42202   -3.70395  Entire home/apt
# 3              Centro        Justicia  40.41995   -3.69764  Entire home/apt
# 4          Arganzuela         Legazpi  40.38985   -3.69011     Private room
#
#    price  minimum_nights                         listing_url  \
# 0     70               1   https://www.airbnb.com/rooms/6369
# ...

# %%
# Investigo valores nulos
airbnb.isnull().sum()
# Out:
# id                       0
# name                     5
# neighbourhood_group      0
# neighbourhood            0
# latitude                 0
# longitude                0
# room_type                0
# price                    0
# minimum_nights           0
# listing_url              0
# description            676
# accommodates             0
# amenities                0
# dtype: int64

# %%
# Los valores nulos que aparecen son sobre las características del alojamiento, modifico estos valores por '-'
'''
for i in list(airbnb.columns):
    airbnb[i] = airbnb[i].replace(np.nan, 0)
'''
airbnb=airbnb.replace(np.nan, 0)
airbnb.isnull().sum() # Compruebo que me he quitado los valores nulos
# Out:
# id                     0
# name                   0
# neighbourhood_group    0
# neighbourhood          0
# latitude               0
# longitude              0
# room_type              0
# price                  0
# minimum_nights         0
# listing_url            0
# description            0
# accommodates           0
# amenities              0
# dtype: int64

# %%
# Corrijo el texto de columnas que considero, con la función 'reescribir', en la que he utilizado regex para los cambios que considero
# Al final no uso esta función, la dejo para más adelante reescribir solo las filas que considere
'''
for i in range(len(list(airbnb['amenities']))):
    for j in ['amenities']:
        airbnb[j][i]=fn.reescribir(airbnb[j][i])
airbnb.head()'''
# Out:
# "\nfor i in range(len(list(airbnb['amenities']))):\n    for j in ['amenities']:\n        airbnb[j][i]=fn.reescribir(airbnb[j][i])\nairbnb.head()"

# %%
airbnb.to_csv("output/Airbnb_Madrid.csv")
